# %%
from nltk import word_tokenize
from collections import defaultdict
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.utils import to_categorical
import pandas as pd
from collections import Counter
from sklearn.model_selection import train_test_split
import io
import numpy as np
import nltk
# Out:
# /Users/I850333/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv('o365Data.csv', dtype=object)

# %%
all_emails = df['EmailBody'].tolist()

# %%
import text_cleaning

# %%
def clean_emails(emails):
    emails = text_cleaning.remove_special_characters(emails)
    emails = text_cleaning.remove_html_words(emails)
    emails = text_cleaning.remove_hex_colors(emails)
    emails = text_cleaning.remove_pixels(emails)
    emails = text_cleaning.remove_new_line_space(emails)
    return emails

# %%
emails = clean_emails(all_emails)
# Out:
# ['label:before', 'relative', 'absolute', 'solid', '&amp;', 'column', '•', 'transparent', 'noinput', 'decoration', 'auto', 'checkbox', 'checked', 'keyframes', '&nbsp;', 'webkit', 'ios', 'mail', 'bug', 'fix', 'div', 'color', 'inherit', 'textdecoration', 'none', 'important', 'fontsize', 'inherit', 'important', 'fontfamily', 'inherit', 'important', 'fontweight', 'inherit', 'important', 'lineheight', 'inherit', 'important', 'text', 'important', 'arrow', 'media', 'screen', 'align-content', 'align-items', 'align-self', 'all', 'animation', 'animation-delay', 'animation-direction', 'animation-duration', 'animation-fill-mode', 'animation-iteration-count', 'animation-name', 'animation-play-state', 'animation-timing-function', 'azimuth', 'backface-visibility', 'background-attachment', 'background-blend-mode', 'background-clip', 'background-color', 'background-image', 'background-origin', 'background-position', 'background-repeat', 'background-size', 'background', 'behavior', 'bleed', 'border-bot
# ...

# %%
receipt_emails = emails

# %%
import mailbox

# %%
mbox = mailbox.mbox('emails.mbox')

# %%
non_receipt_emails = []
for message in mbox:
    payload = message.get_payload(decode=False)
    if isinstance(payload,list):
        non_receipt_emails.append(payload[0])
    else:
        non_receipt_emails.append(payload)

# %%
cleaned_non_receipt_emails = []
for i in range(0,len(non_receipt_emails)):
    try:
        cleaned_non_receipt_emails.append(str(non_receipt_emails[i]))
    except:
        print('couldnt convert email at index: ' + str(i))
# Out:
# couldnt convert email at index: 105
# couldnt convert email at index: 170
# couldnt convert email at index: 178
# couldnt convert email at index: 210
# couldnt convert email at index: 468
# couldnt convert email at index: 489
# couldnt convert email at index: 569
# couldnt convert email at index: 614
# couldnt convert email at index: 626
# couldnt convert email at index: 730
# couldnt convert email at index: 893
# couldnt convert email at index: 942
# couldnt convert email at index: 985
# couldnt convert email at index: 1043
# couldnt convert email at index: 1242
# couldnt convert email at index: 1252
# couldnt convert email at index: 1267
# couldnt convert email at index: 1364
# couldnt convert email at index: 1423
# couldnt convert email at index: 1567
# couldnt convert email at index: 1609
# couldnt convert email at index: 1623
# couldnt convert email at index: 1691
# couldnt convert email at index: 1767
# couldnt convert email at index: 1890
# ...

# %%
cleaned_non_receipt_emails
# Out:
# 27359

# %%
import html2text

# %%
h = html2text.HTML2Text()
h.ignore_links = True

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

def classify(emails, labels):
    X_train, X_test, y_train, y_test = train_test_split(emails, labels, test_size=0.33, random_state=42)
    vectorizer = CountVectorizer()
#     clf = MultinomialNB()
    clf = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=5, tol=None)
    pipe = Pipeline([('vect', vectorizer),
                        ('tfidf', TfidfTransformer()),
                        ('clf', clf)
                        ])
                        
    pipe.fit(X_train, y_train)  
    predicted = pipe.predict(X_test)
    return np.mean(predicted == y_test), clf,vectorizer

# %%
labels = np.zeros(len(cleaned_non_receipt_emails)).tolist() + np.ones(len(receipt_emails)).tolist()

# %%
emails = cleaned_non_receipt_emails + receipt_emails

# %%
import random
combined = list(zip(emails, labels))
random.shuffle(combined)

emails[:], labels[:] = zip(*combined)

# %%
accuracy, clf, vectorizer = classify(emails,labels)
print(accuracy)
print(type(classifier))
# Out:
# 0.9792205692108668
# <class 'sklearn.pipeline.Pipeline'>

# %%
body = "Dear Rare IT, Thank you for your payment of $650.00 USD that was processed on 02/16/2017. Invoice Details Support Website Related Articles: Where Do I Find My Invoice History? Contact Us: 55 Almaden Boulevard, 6th Floor San Jose, CA 95113 Thank you for your business! Zoom Video Communications, Inc."


classifier.predict([body])
# Out:
# array([0.])

# %%
def show_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print ("\t%.4f\t%-15s\t\t%.4f\t%-15s" % (coef_1, fn_1, coef_2, fn_2))

# %%
show_most_informative_features(vectorizer,clf)
# Out:
# 	-2.4584	content        		2.8007	nbsp
# 	-1.3635	text           		1.9429	2018
# 	-1.3354	plain          		1.6663	your
# 	-1.2230	charset        		1.4650	00
# 	-1.1968	transfer       		1.4455	total
# 	-1.1956	encoding       		1.3764	receipt
# 	-1.1833	http           		1.1679	invoice
# 	-1.0977	type           		1.1647	behaviorurl
# 	-1.0781	utf            		1.1256	attached
# 	-1.0518	base64         		1.0497	for
# 	-1.0204	lance          		1.0153	number
# 	-0.9559	3d             		1.0046	100
# 	-0.9157	https          		0.9904	vml
# 	-0.8703	order          		0.9557	uber
# 	-0.8071	com            		0.9551	please
# 	-0.8022	mail           		0.9514	comgt
# 	-0.7789	all            		0.9366	thank
# 	-0.7503	paypal         		0.8669	sansserif
# 	-0.7497	20             		0.8480	body
# 	-0.7262	font           		0.8385	trip

# %%
import eli5
eli5.show_weights(clf, top=10)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1.0
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
# ...
